# %% [markdown]
# # Exploratory Data Analysis (EDA) – Second Quarter Sales Dataset
#
# ## Project Overview
#
# This notebook presents an exploratory data analysis (EDA) of the cleaned second-quarter sales dataset. The analysis aims to explore sales performance, product trends, temporal patterns, and delivery platform performance by applying descriptive statistics and visualizations. The findings provide valuable insights into business performance and establish a foundation for dashboard development and quarterly comparisons.
#
# ## Objectives
#
# The main objectives of this analysis are:
#
# - Evaluate the overall sales performance during the second quarter.
# - Analyze product performance based on revenue, sales quantity, and product returns.
# - Identify sales trends across months, weekdays, and hours.
# - Evaluate the performance of the major delivery platforms.
# - Discover patterns and business insights through descriptive analysis and visualizations.
# - Summarize the key findings to support business decision-making and prepare for quarterly and yearly comparisons.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load the Clean Dataset
#
# Load the cleaned second-quarter sales dataset and verify its structure before starting the exploratory data analysis.

# %%
df = pd.read_excel("../../../Data/Cleaned/clean_q2_data.xlsx", parse_dates=["Date"])

# %% [markdown]
# ## 3. Dataset Overview
#
# This section provides a general overview of the cleaned dataset, including its dimensions, data types, descriptive statistics, and basic business metrics.

# %% [markdown]
# ### 3.1 Dataset Shape

# %%
df.shape
# Out:
# (45143, 8)

# %% [markdown]
# ### 3.2 Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45143 entries, 0 to 45142
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            45143 non-null  datetime64[ns]
#  1   Receipt Number  45143 non-null  object
#  2   Customer        15326 non-null  object
#  3   Product         45143 non-null  object
#  4   Quantity        45143 non-null  float64
#  5   Unit_Price      45143 non-null  float64
#  6   Subtotal        45143 non-null  float64
#  7   Total           15335 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(3)
# memory usage: 2.8+ MB

# %% [markdown]
# ### 3.3 Descriptive Statistics

# %%
df.describe().T
# Out:
#               count                           mean                  min  \
# Date          45143  2025-05-15 01:59:36.952439808  2025-04-01 00:00:27
# Quantity    45143.0                       1.565009                -11.0
# Unit_Price  45143.0                      10.721536                -20.1
# Subtotal    45143.0                      14.367078               -138.0
# Total       15335.0                      42.318721               -186.0
#
#                             25%                  50%                  75%  \
# Date        2025-04-23 07:09:32  2025-05-15 08:09:31  2025-06-05 06:33:59
# Quantity                    1.0                  1.0                  2.0
# Unit_Price                  4.0                  6.0                 12.0
# Subtotal                    4.0                 10.0                 20.0
# Total                      11.0                 25.0                 58.0
#
#                             max        std
# Date        2025-06-30 23:17:19        NaN
# Quantity                  650.0   3.898117
# Unit_Price                138.0  13.138222
# Subtotal                 3900.0  28.285503
# Total                    3900.0  60.792659

# %% [markdown]
# ### 3.4 Missing Values Check

# %%
df.isna().sum()
# Out:
# Date                  0
# Receipt Number        0
# Customer          29817
# Product               0
# Quantity              0
# Unit_Price            0
# Subtotal              0
# Total             29808
# dtype: int64

# %% [markdown]
# > **Note:** The missing values in the **Customer** and **Total** columns are expected and do not indicate data quality issues. Customer information is only recorded for transactions associated with registered customers or delivery applications, while many in-store transactions do not contain customer names. Similarly, the **Total** value represents the overall amount of an entire receipt and is intentionally stored only once for each transaction rather than being repeated for every product line. Therefore, these missing values were retained as they accurately reflect the original transaction structure.

# %% [markdown]
# ### 3.5 Duplicate Records Check

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 3.6 Date Range

# %%
print(df["Date"].min())
print(df["Date"].max())
# Out:
# 2025-04-01 00:00:27
# 2025-06-30 23:17:19

# %% [markdown]
# ### 3.7 Business Summary

# %%
print(f"Total Records : {len(df):,}")
print(f"Unique Orders : {df['Receipt Number'].nunique():,}")
print(f"Unique Products : {df['Product'].nunique():,}")
print(f"Unique Customers : {df['Customer'].nunique():,}")
# Out:
# Total Records : 45,143
# Unique Orders : 15,333
# Unique Products : 135
# Unique Customers : 857

# %% [markdown]
# ## 4. Sales Performance Analysis
#
# This section evaluates the overall sales performance during the second quarter by calculating key business metrics. These key performance indicators (KPIs) provide an overview of the sales volume, revenue, and transaction characteristics, serving as a foundation for the subsequent analyses.

# %% [markdown]
# ### 4.1 Total Revenue

# %%
total_revenue = df["Subtotal"].sum()

print(f"Total Revenue: {total_revenue:,.2f}")
# Out:
# Total Revenue: 648,572.98

# %% [markdown]
# ### 4.2 Total Quantity Sold

# %%
total_quantity = df["Quantity"].sum()

print(f"Total Quantity Sold: {total_quantity:,.0f}")
# Out:
# Total Quantity Sold: 70,649

# %% [markdown]
# ### 4.3 Total Orders

# %%
total_orders = df["Receipt Number"].nunique()

print(f"Total Orders: {total_orders:,}")
# Out:
# Total Orders: 15,333

# %% [markdown]
# ### 4.4 Average Order Value (AOV)

# %%
average_order_value = (
    df.groupby("Receipt Number")["Subtotal"]
      .sum()
      .mean()
)

print(f"Average Order Value: {average_order_value:.2f}")
# Out:
# Average Order Value: 42.30

# %% [markdown]
# ### 4.5 Average Selling Price

# %%
average_price = df["Unit_Price"].mean()

print(f"Average Selling Price: {average_price:.2f}")
# Out:
# Average Selling Price: 10.72

# %% [markdown]
# ### 4.6 Average Items per Order

# %%
average_items = (
    df.groupby("Receipt Number")["Quantity"]
      .sum()
      .mean()
)

print(f"Average Items per Order: {average_items:.2f}")
# Out:
# Average Items per Order: 4.61

# %% [markdown]
# ### 4.7 Summary Table

# %%
sales_summary = pd.DataFrame({
    "Metric": [
        "Total Revenue",
        "Total Quantity Sold",
        "Total Orders",
        "Average Order Value",
        "Average Selling Price",
        "Average Items per Order"
    ],
    "Value": [
        round(total_revenue, 2),
        int(total_quantity),
        total_orders,
        round(average_order_value, 2),
        round(average_price, 2),
        round(average_items, 2)
    ]
})

sales_summary
# Out:
#                     Metric      Value
# 0            Total Revenue  648572.98
# 1      Total Quantity Sold   70649.00
# 2             Total Orders   15333.00
# 3      Average Order Value      42.30
# 4    Average Selling Price      10.72
# 5  Average Items per Order       4.61

# %% [markdown]
# ## 5. Product Analysis
#
# This section evaluates product performance by examining the number of unique products, sales volume, revenue contribution, and product returns. The analysis helps identify the best-performing products, the lowest-selling products, and the products with the highest number of returned items during the second quarter.

# %% [markdown]
# ### 5.1 Number of Unique Products
#
# Calculate the total number of unique products available in the dataset.

# %%
unique_products = df["Product"].nunique()

print(f"Unique Products: {unique_products}")
# Out:
# Unique Products: 135

# %% [markdown]
# ### 5.2 Top Products by Revenue
#
# Identify the products that generated the highest revenue.

# %%
top_revenue_products = (
    df.groupby("Product")["Subtotal"]
      .sum()
      .sort_values(ascending=False)
)

top_revenue_products.head(10)
# Out:
# Product
# صحن تكا روب          35730.60
# سيخ تكا روب          34846.60
# صحن سبشل تكا         26045.56
# صحن تكا ليمون        24756.66
# صحن 21 سيخ مشكل      23644.00
# صاروخ تكا لحم روب    20737.40
# حمص                  18936.40
# باجا كوارع           18018.71
# مشكل مشويات وسط      17450.80
# هريس لحم صغير        17215.60
# Name: Subtotal, dtype: float64

# %% [markdown]
# ### 5.3 Top Products by Quantity Sold
#
# Identify the products with the highest sales volume.

# %%
top_quantity_products = (
    df.groupby("Product")["Quantity"]
      .sum()
      .sort_values(ascending=False)
)

top_quantity_products.head(10)
# Out:
# Product
# سيخ تكا روب          6855.0
# ماء                  3487.2
# سندويش بيض بالجبن    3064.0
# كينزا كولا           2874.0
# سندويش كبدة          2858.0
# سيخ تكا ليمون        2651.0
# سيخ تكا دجاج         2283.0
# صحن بطاطس            1988.0
# حمص                  1864.0
# سندويش فلافل         1863.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ### 5.4 Lowest-Selling Products
#
# Identify the products with the lowest sales volume.

# %%
lowest_products = (
    df.groupby("Product")["Quantity"]
      .sum()
      .sort_values(ascending=True)
)

lowest_products.head(10)
# Out:
# Product
# عصير برتقال                                1.0
# صحن كباب مشكل (نسخة)                       1.0
# خبز زعتر بالخضار                           2.0
# صحن مشكل كبير                              3.0
# صحن لحم مفروم بالجين                       4.0
# عصير توت                                   4.0
# سندويش فلافل مع البيض دبل بالخبز العربي    4.0
# سندويش فلافل بيض بالجبن                    6.0
# صحن لحم مفروم بالحمص                       6.0
# نص صحن فول                                 7.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ### 5.5 Most Returned Products
#
# Identify the products with the highest number of returned items based on negative sales quantities.

# %%
returned_products = (
    df[df["Quantity"] < 0]
      .groupby("Product")["Quantity"]
      .sum()
      .abs()
      .sort_values(ascending=False)
)

returned_products.head(10)
# Out:
# Product
# سندويش بيض بالجبن    30.0
# ماء                  27.0
# سندويش كبدة          26.0
# كينزا كولا           25.0
# خبز عربي تنور        16.0
# سندويش بيض مسلوق     15.0
# هريس لحم صغير        14.0
# سيخ تكا ليمون        14.0
# سندويش مفروم         13.0
# صاروخ تكا دجاج       11.0
# Name: Quantity, dtype: float64

# %% [markdown]
# ### 5.6 Product Performance Summary
#
# Summarize the overall performance of each product, including total revenue, quantity sold, and average selling price.

# %%
product_summary = (
    df.groupby("Product")
      .agg(
          Revenue=("Subtotal", "sum"),
          Quantity_Sold=("Quantity", "sum"),
          Average_Price=("Unit_Price", "mean")
      )
      .sort_values("Revenue", ascending=False)
)

product_summary
# Out:
#                                    Revenue  Quantity_Sold  Average_Price
# Product
# صحن تكا روب                       35730.60         1282.0      27.961938
# سيخ تكا روب                       34846.60         6855.0       5.112580
# صحن سبشل تكا                      26045.56          531.0      49.053333
# صحن تكا ليمون                     24756.66          819.0      30.131919
# صحن 21 سيخ مشكل                   23644.00          196.0     120.902299
# ...                                    ...            ...            ...
# عصير توت                             16.00            4.0       4.000000
# خبز بر                               14.00           14.0       1.000000
# خبز زعتر بالخضار                      8.00            2.0       4.000000
# عصير برتقال                           4.00            1.0       4.000000
#  خصم 15.0% على القيمة الإجمالية    -471.61           81.0      -5.821556
#
# [135 rows x 3 columns]

# %% [markdown]
# ## 6. Time-Based Analysis
#
# This section analyzes sales performance over time by examining revenue and transaction patterns across different months, weekdays, and hours. The objective is to identify sales trends and peak business periods during the second quarter.

# %% [markdown]
# ### 6.1 Date Features
#
# Extract additional date and time features from the transaction date to support the time-based analysis.

# %%
# Extract useful date and time features.
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month_name()
df["Month_Number"] = df["Date"].dt.month
df["Weekday"] = df["Date"].dt.day_name()
df["Hour"] = df["Date"].dt.hour

# %% [markdown]
# ### 6.2 Sales by Month
#
# Analyze the monthly sales revenue to identify sales trends throughout the quarter.

# %%
monthly_sales = (
    df.groupby(["Month_Number", "Month"], as_index=False)["Subtotal"]
      .sum()
      .sort_values("Month_Number")
)

monthly_sales
# Out:
#    Month_Number  Month   Subtotal
# 0             4  April  216684.10
# 1             5    May  234395.82
# 2             6   June  197493.06

# %% [markdown]
# ### 6.3 Orders by Month
#
# Analyze the number of unique orders placed each month.

# %%
monthly_orders = (
    df.groupby(["Month_Number", "Month"], as_index=False)["Receipt Number"]
      .nunique()
      .rename(columns={"Receipt Number": "Orders"})
      .sort_values("Month_Number")
)

monthly_orders
# Out:
#    Month_Number  Month  Orders
# 0             4  April    5299
# 1             5    May    5639
# 2             6   June    4395

# %% [markdown]
# ### 6.4 Sales by Weekday
#
# Analyze sales revenue across the days of the week to identify the busiest sales days.

# %%
weekday_order = [
    "Sunday",
    "Monday",
    "Tuesday",
    "Wednesday",
    "Thursday",
    "Friday",
    "Saturday"
]

df["Weekday"] = pd.Categorical(
    df["Weekday"],
    categories=weekday_order,
    ordered=True
)

weekday_sales = (
    df.groupby("Weekday", observed=True)["Subtotal"]
      .sum()
      .sort_index()
)

weekday_sales
# Out:
# Weekday
# Sunday        77793.50
# Monday        82455.46
# Tuesday       89488.76
# Wednesday     87852.14
# Thursday     110124.72
# Friday       107246.74
# Saturday      93611.66
# Name: Subtotal, dtype: float64

# %% [markdown]
# ### 6.5 Orders by Weekday
#
# Analyze the number of unique orders across the days of the week.

# %%
weekday_orders = (
    df.groupby("Weekday", observed=True)["Receipt Number"]
      .nunique()
      .sort_index()
)

weekday_orders
# Out:
# Weekday
# Sunday       2147
# Monday       2152
# Tuesday      2338
# Wednesday    2276
# Thursday     2507
# Friday       1931
# Saturday     1982
# Name: Receipt Number, dtype: int64

# %% [markdown]
# ### 6.6 Sales by Hour
#
# Analyze sales revenue by hour to identify peak shopping hours.

# %%
hourly_sales = (
    df.groupby("Hour")["Subtotal"]
      .sum()
      .sort_index()
)

hourly_sales
# Out:
# Hour
# 0      14089.40
# 1        952.00
# 2        146.50
# 3        111.00
# 5        370.00
# 6      22426.05
# 7      35638.85
# 8      32317.46
# 9      30121.61
# 10     25907.31
# 11      4455.65
# 12       386.00
# 13        17.00
# 14       118.00
# 15       338.00
# 16        40.00
# 17      3501.00
# 18     13118.86
# 19     45776.62
# 20     94873.18
# 21    120107.03
# 22    117285.86
# 23     86475.60
# Name: Subtotal, dtype: float64

# %% [markdown]
# ### 6.7 Orders by Hour
#
# Analyze the number of unique orders placed during each hour of the day.

# %%
hourly_orders = (
    df.groupby("Hour")["Receipt Number"]
      .nunique()
      .sort_index()
)

hourly_orders
# Out:
# Hour
# 0      177
# 1       25
# 2        3
# 3        3
# 5       19
# 6     1358
# 7     1867
# 8     1548
# 9     1289
# 10    1105
# 11     248
# 12      16
# 13       2
# 14       4
# 15       4
# 16       3
# 17      33
# 18     303
# 19     920
# 20    1503
# 21    1819
# 22    1765
# 23    1319
# Name: Receipt Number, dtype: int64

# %% [markdown]
# ### 6.8 Peak Sales Periods
#
# Identify the month, weekday, and hour with the highest sales revenue and the highest number of orders.

# %%
# Peak sales month
peak_month = monthly_sales.loc[
    monthly_sales["Subtotal"].idxmax(),
    "Month"
]

# Peak sales weekday
peak_weekday = weekday_sales.idxmax()

# Peak sales hour
peak_hour = hourly_sales.idxmax()

# Peak orders month
peak_orders_month = monthly_orders.loc[
    monthly_orders["Orders"].idxmax(),
    "Month"
]

# Peak orders weekday
peak_orders_weekday = weekday_orders.idxmax()

# Peak orders hour
peak_orders_hour = hourly_orders.idxmax()

print(f"Peak Sales Month   : {peak_month}")
print(f"Peak Sales Weekday : {peak_weekday}")
print(f"Peak Sales Hour    : {peak_hour}:00\n")

print(f"Peak Orders Month   : {peak_orders_month}")
print(f"Peak Orders Weekday : {peak_orders_weekday}")
print(f"Peak Orders Hour    : {peak_orders_hour}:00")
# Out:
# Peak Sales Month   : May
# Peak Sales Weekday : Thursday
# Peak Sales Hour    : 21:00
#
# Peak Orders Month   : May
# Peak Orders Weekday : Thursday
# Peak Orders Hour    : 7:00

# %% [markdown]
# ## 7. Sales Channel Analysis
#
# This section analyzes the performance of online delivery platforms by evaluating their contribution to sales revenue and transaction volume during the second quarter.

# %% [markdown]
# ### 7.1 Delivery Platforms
#
# Identify the major delivery platforms included in the analysis. Platforms with only a negligible number of transactions (e.g., a single transaction) are excluded to ensure that the analysis focuses on meaningful sales patterns and avoids misleading comparisons.

# %%
delivery_apps = [
    "عملاء شوكة",
    "عملاء هنقرستيشن",
    "عملاء كيتا"
]

platform_df = df[df["Customer"].isin(delivery_apps)]

# %% [markdown]
# ### 7.2 Revenue by Delivery Platform
#
# Analyze the total sales revenue generated by each delivery platform.

# %%
platform_sales = (
    platform_df.groupby("Customer")["Subtotal"]
    .sum()
    .sort_values(ascending=False)
)

platform_sales
# Out:
# Customer
# عملاء كيتا         17635.48
# عملاء شوكة         16833.71
# عملاء هنقرستيشن     2898.00
# Name: Subtotal, dtype: float64

# %% [markdown]
# ### 7.3 Orders by Delivery Platform
#
# Analyze the number of unique orders received from each delivery platform.

# %%
platform_orders = (
    platform_df.groupby("Customer")["Receipt Number"]
    .nunique()
    .sort_values(ascending=False)
)

platform_orders
# Out:
# Customer
# عملاء شوكة         811
# عملاء كيتا         804
# عملاء هنقرستيشن     88
# Name: Receipt Number, dtype: int64

# %% [markdown]
# ### 7.4 Average Order Value by Platform
#
# Calculate the average order value for each delivery platform.

# %%
platform_aov = (
    platform_df.groupby(["Customer", "Receipt Number"])["Subtotal"]
    .sum()
    .groupby("Customer")
    .mean()
    .sort_values(ascending=False)
)

platform_aov
# Out:
# Customer
# عملاء هنقرستيشن    32.931818
# عملاء كيتا         21.934677
# عملاء شوكة         20.756732
# Name: Subtotal, dtype: float64

# %% [markdown]
# ### 7.5 Revenue Contribution
#
# Calculate the percentage contribution of each delivery platform to the total sales revenue.

# %%
platform_contribution = (
    (platform_sales / platform_sales.sum()) * 100
).round(2)

platform_contribution
# Out:
# Customer
# عملاء كيتا         47.20
# عملاء شوكة         45.05
# عملاء هنقرستيشن     7.76
# Name: Subtotal, dtype: float64

# %% [markdown]
# ## 8. Data Visualization
#
# This section presents graphical representations of the key findings obtained from the exploratory data analysis. The visualizations provide an intuitive understanding of sales performance, product trends, time-based patterns, and delivery platform contributions during the second quarter.

# %% [markdown]
# ### 8.1 Top 10 Products by Revenue
#
# Visualize the ten products that generated the highest sales revenue.

# %%
plt.figure(figsize=(12, 6))

top_revenue_products.head(10).plot(kind="bar")

plt.title("Top 10 Products by Revenue")
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.2 Top 10 Products by Quantity Sold
#
# Visualize the ten products with the highest sales volume.

# %%
plt.figure(figsize=(12, 6))

top_quantity_products.head(10).plot(kind="bar")

plt.title("Top 10 Products by Quantity Sold")
plt.xlabel("Product")
plt.ylabel("Quantity Sold")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.3 Lowest-Selling Products
#
# Visualize the products with the lowest sales quantity.

# %%
plt.figure(figsize=(12, 6))

lowest_products.head(10).plot(kind="bar")

plt.title("Lowest Selling Products")
plt.xlabel("Product")
plt.ylabel("Quantity Sold")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.4 Most Returned Products
#
# Visualize the products with the highest number of returned items.

# %%
plt.figure(figsize=(12, 6))

returned_products.head(10).plot(kind="bar")

plt.title("Most Returned Products")
plt.xlabel("Product")
plt.ylabel("Returned Quantity")
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.5 Monthly Sales
#
# Visualize the total sales revenue for each month.

# %%
plt.figure(figsize=(8, 5))

plt.plot(
    monthly_sales["Month"],
    monthly_sales["Subtotal"],
    marker="o"
)

plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Revenue")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.6 Sales by Weekday
#
# Visualize sales revenue across the days of the week.

# %%
plt.figure(figsize=(10, 5))

weekday_sales.plot(kind="bar")

plt.title("Sales by Weekday")
plt.xlabel("Weekday")
plt.ylabel("Revenue")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.7 Sales by Hour
#
# Visualize hourly sales revenue to identify peak business hours.

# %%
plt.figure(figsize=(12, 5))

plt.plot(
    hourly_sales.index,
    hourly_sales.values,
    marker="o"
)

plt.title("Sales by Hour")
plt.xlabel("Hour")
plt.ylabel("Revenue")

plt.xticks(range(24))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.8 Revenue by Delivery Platform
#
# Visualize the sales revenue generated by each delivery platform.

# %%
plt.figure(figsize=(8, 5))

platform_sales.plot(kind="bar")

plt.title("Revenue by Delivery Platform")
plt.xlabel("Delivery Platform")
plt.ylabel("Revenue")

plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.9 Orders by Delivery Platform
#
# Visualize the number of orders received from each delivery platform.

# %%
plt.figure(figsize=(8, 5))

platform_orders.plot(kind="bar")

plt.title("Orders by Delivery Platform")
plt.xlabel("Delivery Platform")
plt.ylabel("Number of Orders")

plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 8.10 Delivery Platform Revenue Contribution
#
# Visualize the percentage contribution of each delivery platform to the total sales revenue.

# %%
plt.figure(figsize=(7, 7))

plt.pie(
    platform_contribution,
    labels=platform_contribution.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Revenue Contribution by Delivery Platform")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Key Insights
#
# - The second quarter generated a total revenue of **648,572.98** from **15,333** completed orders, with an average order value of **42.30**.
# - The cleaned dataset contains **135 unique products**, **857 unique customers**, and **15,333** unique transactions, providing a comprehensive overview of sales activity during the second quarter.
# - **May** recorded the highest sales revenue (**234,395.82**) and the highest number of orders (**5,639**), making it the best-performing month of the quarter.
# - **Thursday** generated the highest sales revenue and also recorded the largest number of completed orders, indicating that it was the busiest day of the week.
# - Sales revenue peaked at **9:00 PM (21:00)**, while the highest number of orders was recorded at **7:00 AM (07:00)**, reflecting different customer purchasing patterns throughout the day.
# - **صحن تكا روب** generated the highest sales revenue, followed by **سيخ تكا روب** and **صحن سبشل تكا**, making them the leading revenue-generating products during the quarter.
# - **سيخ تكا روب** recorded the highest sales quantity, followed by **ماء** and **سندويش بيض بالجبن**, indicating strong customer demand for these products.
# - Among the analyzed delivery platforms, **عملاء كيتا** generated the highest sales revenue and achieved the highest average order value, while **عملاء شوكة** recorded the largest number of completed orders.
# - The highest returned quantities were observed for **سندويش بيض بالجبن**, **ماء**, and **سندويش كبدة**, suggesting that these products experienced more returns than other items during the analyzed period.
